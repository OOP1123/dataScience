# %% [markdown]
# # Healthcare Dataset

# %% [markdown]
# # About Data:

# %% [markdown]
# # Dataset Information:
#
# Each column provides specific information about the patient, their admission, and the healthcare services provided, making this dataset suitable for various data analysis and modeling tasks in the healthcare domain. Here's a brief explanation of each column in the dataset -
#
# Name: This column represents the name of the patient associated with the healthcare record.
#
# Age: The age of the patient at the time of admission, expressed in years.
#
# Gender: Indicates the gender of the patient, either "Male" or "Female."
#
# Blood Type: The patient's blood type, which can be one of the common blood types (e.g., "A+", "O-", etc.).
#
# Medical Condition: This column specifies the primary medical condition or diagnosis associated with the patient, such as "Diabetes," "Hypertension," "Asthma," and more.
#
# Date of Admission: The date on which the patient was admitted to the healthcare facility.
#
# Doctor: The name of the doctor responsible for the patient's care during their admission.
#
# Hospital: Identifies the healthcare facility or hospital where the patient was admitted.
#
# Insurance Provider: This column indicates the patient's insurance provider, which can be one of several options, including "Aetna," "Blue Cross," "Cigna," "UnitedHealthcare," and "Medicare."
#
# Billing Amount: The amount of money billed for the patient's healthcare services during their admission. This is expressed as a floating-point number.
#
# Room Number: The room number where the patient was accommodated during their admission.
#
# Admission Type: Specifies the type of admission, which can be "Emergency," "Elective," or "Urgent," reflecting the circumstances of the admission.
#
# Discharge Date: The date on which the patient was discharged from the healthcare facility, based on the admission date and a random number of days within a realistic range.
#
# Medication: Identifies a medication prescribed or administered to the patient during their admission. Examples include "Aspirin," "Ibuprofen," "Penicillin," "Paracetamol," and "Lipitor."
#
# Test Results: Describes the results of a medical test conducted during the patient's admission. Possible values include "Normal," "Abnormal," or "Inconclusive," indicating the outcome of the test

# %%
##import packages to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\DELL\Desktop\healthcare_dataset.csv')

# %% [markdown]
# # Explore Data

# %% [markdown]
# Tip: In this section of the report, you will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. Make sure that you document your steps carefully and justify your cleaning decisions. We will start with addressing General properities about the dataset.

# %%
data.shape
# Out:
# (10000, 15)

# %%
data.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Date of Admission          Doctor                   Hospital  \
# 0        11/17/2022  Patrick Parker           Wallace-Hamilton
# 1          6/1/2023   Diane Jackson  Burke, Griffin and Cooper
# 2          1/9/2019      Paul Baker                 Walton LLC
# 3          5/2/2020  Brian Chandler                 Garcia Ltd
# 4          7/9/2021  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0           Medicare     37490.98336          146       Elective
# ...

# %%
data.tail()
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# 9995         7/29/2022       Samuel Moody   Wood, Martin and Simmons
# 9996          1/6/2022  Christopher Yates               Nash-Krueger
# 9997          7/1/2022   Robert Nicholson            Larson and Sons
# 9998          2/6/2020        Jamie Lewis               Wilson-Lyons
# 9999         3/22/2023        Tasha Avila  Torres, Young and Stewart
#
#      Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %% [markdown]
# ### cheaking data type and missing value

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
data.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0     False  False   False       False              False              False
# 1     False  False   False       False              False              False
# 2     False  False   False       False              False              False
# 3     False  False   False       False              False              False
# 4     False  False   False       False              False              False
# ...     ...    ...     ...         ...                ...                ...
# 9995  False  False   False       False              False              False
# 9996  False  False   False       False              False              False
# 9997  False  False   False       False              False              False
# 9998  False  False   False       False              False              False
# ...

# %%
data.describe().round(2)
# Out:
#             Age  Billing Amount  Room Number
# count  10000.00        10000.00     10000.00
# mean      51.45        25516.81       300.08
# std       19.59        14067.29       115.81
# min       18.00         1000.18       101.00
# 25%       35.00        13506.52       199.00
# 50%       52.00        25258.11       299.00
# 75%       68.00        37733.91       400.00
# max       85.00        49995.90       500.00

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Data cleaning is the process of fixing or removing incorrect, duplicate,noisy, or incomplete data within a dataset. Thorugh data cleaning phase, data wrangling has been conducted for modifying the data into a more usable form.

# %%
#check for NULL values if any in each column
data.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
sns.heatmap(data.isnull(),annot=False,yticklabels=False)
plt.show()

# %%
#check if there are duplicate records in the data
data.duplicated().sum()
# Out:
# 0

# %%
# Date of Admission and Discharge Date have dtype as object let's format it to datetime
for date in ['Date of Admission','Discharge Date']:
    data[date] = pd.to_datetime(data[date])
#calculate the no: of days patients got admitted in hospital
data['Days Hospitalized'] = (data['Discharge Date'] - data['Date of Admission']).dt.days
data['Days Hospitalized'] = data['Days Hospitalized'].astype(int)
data['Days Hospitalized']
# Out:
# 0       14
# 1       14
# 2       30
# 3        1
# 4       24
#         ..
# 9995     4
# 9996    23
# 9997    14
# 9998    20
# 9999    24
# Name: Days Hospitalized, Length: 10000, dtype: int32

# %%
#Dropping Unnecessary Variables
data.drop('Date of Admission', axis=1, inplace=True)
data.drop('Discharge Date', axis=1, inplace=True)
data.drop('Room Number', axis=1, inplace=True)

# %%
data.head()
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 0      Tiffany Ramirez   81  Female         O-          Diabetes
# 1          Ruben Burns   35    Male         O+            Asthma
# 2            Chad Byrd   61    Male         B-           Obesity
# 3    Antonio Frederick   49    Male         B-            Asthma
# 4  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#            Doctor                   Hospital Insurance Provider  \
# 0  Patrick Parker           Wallace-Hamilton           Medicare
# 1   Diane Jackson  Burke, Griffin and Cooper   UnitedHealthcare
# 2      Paul Baker                 Walton LLC           Medicare
# 3  Brian Chandler                 Garcia Ltd           Medicare
# 4  Dustin Griffin    Jones, Brown and Murray   UnitedHealthcare
#
#    Billing Amount Admission Type   Medication  Test Results  Days Hospitalized
# 0     37490.98336       Elective      Aspirin  Inconclusive                 14
# ...

# %% [markdown]
# # Data Analysis Process

# %% [markdown]
# # Questions asked from the data

# %% [markdown]
# ## Research Question: find the range of age:

# %%
#finding the range of ages
sns.displot(data['Age'], kde='True', bins='auto')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# From the histogram, we can see patients aged around 20 and over 80 have highest count.

# %% [markdown]
# # Research Question : information about the percentage distribution of each blood group in the dataset.

# %%
# Checking the blodd percentage in the  data set
data['Blood Type'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',
     title="Visualize the Blood type percentage in the data",
      explode=[0,0,0,0,0,0,0,0.001],
      labels=['AB-','AB+','B-','O+','O-','B+','A+','A-'], 
      colors=['#f72585','#778da9','#9b2226','#000814','#83c5be','#a3a380'], 
      autopct='%1.2f%%',
      pctdistance=0.6, 
      shadow=True)
plt.show()

# %% [markdown]
# AB- is the leading blood group in the dataset, followed by AB+.

# %% [markdown]
# # Research Question : Information about the top 10 regular customers based on relevant criteria in the dataset.

# %%
# Checking the regular customers
data['Name'].value_counts().sort_values(ascending=False).head(10)\
.plot(kind='bar',figsize=(10,5),title="Regular patients in the hostpital",color=['#588157','#f77f00','#003049','#a8dadc','#9e2a2b'])
plt.xlabel("Patients names")
plt.ylabel("How many times they visit the hospital")
plt.show()

# %% [markdown]
# Michel Janson and James Janson are the top patients, each having visited the hospital 6 times.

# %% [markdown]
# # Research Question : Information about the percentage distribution of genders in the dataset.

# %%
# Find the Gender percentage in the data set
data['Gender'].value_counts().sort_values(ascending=False)\
.plot(kind='pie',title="Visualize the Gender percentage in the data",
      explode=[0,0.01],
      labels=['Female','Male'], 
      colors=['#ff7d00','#1b263b'], 
      autopct='%1.2f%%',
      shadow=True)
plt.show()

# %% [markdown]
# Number of male and female patients are almost equal.

# %% [markdown]
# # Research Question : Information about the medications used for various medical conditions in the dataset.

# %%
 ##Which medication used different medical conditions 
data.groupby('Medical Condition')['Medication'].value_counts().sort_values(ascending=False)\
.unstack().style.background_gradient(cmap='GnBu_r')
# Out:
# <style type="text/css">
# #T_7d979_row0_col0, #T_7d979_row5_col0 {
#   background-color: #54b6d1;
#   color: #f1f1f1;
# }
# #T_7d979_row0_col1 {
#   background-color: #4db2d3;
#   color: #f1f1f1;
# }
# #T_7d979_row0_col2, #T_7d979_row1_col3, #T_7d979_row2_col0, #T_7d979_row3_col1, #T_7d979_row5_col4 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_7d979_row0_col3 {
#   background-color: #53b6d1;
#   color: #f1f1f1;
# }
# #T_7d979_row0_col4, #T_7d979_row1_col0, #T_7d979_row2_col1, #T_7d979_row2_col3, #T_7d979_row4_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_7d979_row1_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_7d979_row1_col2 {
#   background-color: #c8eac3;
#   color: #000000;
# }
# #T_7d979_row1_col4 {
#   background-color: #51b5d2;
#   color: #f1f1f1;
# }
# #T_7d979_row2_col2 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_7d979_row2_col4 {
#   background-color: #eef8e7;
#   color: #000000;
# }
# ...

# %% [markdown]
# For arthritis conditions, Penicillin medication is used, while for asthma, aspirin is prescribed.

# %% [markdown]
# # Research Question: Find the which insurace are providing insurance for diabetes:

# %%
# Find the which insurace are providing insurance for diabetes
diabetes=data['Medical Condition']=='Diabetes'
data.loc[diabetes]['Insurance Provider'].value_counts()\
.plot(kind='pie',
     title="Visualize the diabetes  with insurance provider percentage in the data",
      explode=[0,0,0,0,0.01],
      labels=['Blue Cross','Medicare','Aetna','Cigna','UnitedHealthcare'], 
      colors=['#6b9080','#cce3de','#8ac926','#fc6e6e','#17c3b2'], 
      autopct='%1.2f%%',
      shadow=True)
# Out:
# <Axes: title={'center': 'Visualize the diabetes  with insurance provider percentage in the data'}, ylabel='count'>

# %% [markdown]
# blue cross percentage is 20.89%.
#
# medicare percentage is 20.15%.

# %% [markdown]
# # Research Question: finding each Medical Condition percentage:

# %%
#finding each Medical Condition percentage
sns.countplot(x='Medical Condition',data=data)
# Out:
# <Axes: xlabel='Medical Condition', ylabel='count'>

# %% [markdown]
# Although medical condition counts are pretty similar, asthma and cancer occupy the highest two places.

# %% [markdown]
# # Research Question :Identify and display the top 10 hospitals with the highest charges paid by patients.

# %%
# Top 10 hight fees colleting hosptial
data.groupby('Hospital')['Billing Amount'].sum().sort_values(ascending=False).head(10)\
.plot(kind='barh',figsize=(10,6),color=['#52b69a','#5fa8d3','#0d3b66','#adc178','#6930c3'])
plt.title("Top 10 high bills paying hospital")
plt.xlabel("Sum of the amount")
plt.ylabel("Hospital name")
plt.show()

# %% [markdown]
# # Research Question : Determine the doctor who earns the most.

# %% [markdown]
# the smith and sons is the high bill paying hospital

# %%
# Find the which doctor mostly earn 
data.groupby('Doctor')['Billing Amount'].sum().sort_values(ascending=False).head(10)\
.plot(kind='bar',figsize=(10,6),title="Top 10 most costly doctors",color=['#dedbd2','#ee964b','#ffe5d9','#252422','#adc178'])
plt.xlabel('Doctor names')
plt.ylabel('Billing Amount')
plt.show()

# %% [markdown]
# D/Michael Johanson is the most costly doctor

# %% [markdown]
# # Research Question : Explore and analyze the relationship between medical conditions and admission types, presenting the findings visually.

# %%
# Find the admision type with different madical condition 
data.groupby('Medical Condition')['Admission Type'].value_counts()\
.unstack().style.background_gradient(cmap='seismic_r')
# Out:
# <style type="text/css">
# #T_b1f14_row0_col0 {
#   background-color: #000055;
#   color: #f1f1f1;
# }
# #T_b1f14_row0_col1, #T_b1f14_row3_col2, #T_b1f14_row5_col0 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_b1f14_row0_col2 {
#   background-color: #fc0000;
#   color: #f1f1f1;
# }
# #T_b1f14_row1_col0, #T_b1f14_row2_col1, #T_b1f14_row4_col1, #T_b1f14_row4_col2 {
#   background-color: #00004c;
#   color: #f1f1f1;
# }
# #T_b1f14_row1_col1 {
#   background-color: #c9c9ff;
#   color: #000000;
# }
# #T_b1f14_row1_col2 {
#   background-color: #0000ef;
#   color: #f1f1f1;
# }
# #T_b1f14_row2_col0 {
#   background-color: #0000f2;
#   color: #f1f1f1;
# }
# #T_b1f14_row2_col2 {
#   background-color: #c1c1ff;
#   color: #000000;
# }
# #T_b1f14_row3_col0 {
#   background-color: #ff6969;
#   color: #f1f1f1;
# }
# #T_b1f14_row3_col1 {
#   background-color: #b5b5ff;
#   color: #000000;
# }
# #T_b1f14_row4_col0 {
#   background-color: #ce0000;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# visualize the medical conditions with admission types.

# %%
data.head(1)
# Out:
#               Name  Age  Gender Blood Type Medical Condition          Doctor  \
# 0  Tiffany Ramirez   81  Female         O-          Diabetes  Patrick Parker
#
#            Hospital Insurance Provider  Billing Amount Admission Type  \
# 0  Wallace-Hamilton           Medicare     37490.98336       Elective
#
#   Medication  Test Results  Days Hospitalized
# 0    Aspirin  Inconclusive                 14

# %% [markdown]
# # Research Question : information about   average amount for the gender with billing amount.

# %%
# Let's find the average amount for the gender with billing amount
pd.DataFrame(data.groupby('Gender')['Billing Amount'].mean().sort_values(ascending=False)).style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_3ef59_row0_col0 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_3ef59_row1_col0 {
#   background-color: #def5e5;
#   color: #000000;
# }
# </style>
# <table id="T_3ef59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ef59_level0_col0" class="col_heading level0 col0" >Billing Amount</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Gender</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ef59_level0_row0" class="row_heading level0 row0" >Male</th>
#       <td id="T_3ef59_row0_col0" class="data row0 col0" >25550.215933</td>
#     </tr>
#     <tr>
#       <th id="T_3ef59_level0_row1" class="row_heading level0 row1" >Female</th>
#       <td id="T_3ef59_row1_col0" class="data row1 col0" >25484.385085</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# the average amount for male with billing amount is greater than the female.

# %% [markdown]
# # Research Question : information about the smit and sons hospital insuarance providers

# %%
# Find the smit and sons hospital insuarance providers 
data.groupby('Hospital')['Insurance Provider'].value_counts().loc['Smith and Sons']\
.plot(kind='bar',title="Smith and Sons High insurance agent",figsize=(10,4),color=['#84a98c','#880d1e','#072ac8','#cbeef3','#31572c'])
plt.xlabel("Insurance Agent")
plt.ylabel("Count of values")
plt.show()

# %% [markdown]
# medicare and aetna is equal to each other.
#
# then blue cross.
#
# at last cinga and unitedhealthcare is equal to each other.

# %% [markdown]
# # Research Question : information about billing amount by admission type.

# %%
# Boxplot of Billing Amount by Admission Type
plt.figure(figsize=(10, 6))
sns.boxplot(x='Admission Type', y='Billing Amount', data=data)
plt.xlabel('Admission Type')
plt.ylabel('Billing Amount')
plt.title('Billing Amount by Admission Type')
plt.show()

# %% [markdown]
# From the boxplot, we can see that the Average Billing amount is almost equle for admission type

# %% [markdown]
# # Research Question: finding the TestResult percentage:

# %%
#finding the TestResult percentage
data['Test Results'].value_counts().plot(kind='pie',autopct="%.2f%%")
plt.show()

# %% [markdown]
# Abnormal is the most rebeted TestResults

# %%
# To visualize the 
plt.figure(figsize=(10,5))
for i in ['Medical Condition','Insurance Provider','Blood Type','Gender']:
    sns.countplot(data=data,x=i,hue='Test Results',palette='tab10')
    plt.title(f'The information about {i} to compare the test result')
    plt.xlabel(f'The {i} information')
    plt.ylabel('Test Results')
    plt.show()

# %%
#
sns.boxplot(x= 'Medical Condition', y='Days Hospitalized', data=data)
# Out:
# <Axes: xlabel='Medical Condition', ylabel='Days Hospitalized'>

# %%
#finding Correlation
from sklearn.preprocessing import LabelEncoder
df2 = data.copy()
lc = LabelEncoder()
for col in df2.columns:
    if col!='Age':
        df2[col]=lc.fit_transform(df2[col])

        
corr_matrix = df2.corr()

# Create a heatmap
plt.figure(figsize=(20, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#plotting histograms to find the frequency of numeric columns (age, billing amount and days hospitalized)
for col in data.columns:
    if data[col].dtype == 'int' or data[col].dtype == 'float':
        plt.figure(figsize = (15,6))
        plt.style.use('seaborn-v0_8-dark-palette')
        plt.subplot(3,3,3)
        sns.histplot(data[col],kde = True,color = 'darkblue')
        plt.ylabel('Frequency',fontsize = 10)
        plt.xlabel(col,fontsize = 10)
        plt.title(f'Distribution of {col} among Patients',fontsize = 12,weight = 'bold')
        print("_"*100)
        plt.show()
# Out:
# ____________________________________________________________________________________________________
# ____________________________________________________________________________________________________

# %% [markdown]
# # conclusion

# %% [markdown]
# Compared to male, there are high female patients.
#
# Most patients have the blood type of AB-.
#
# Asthma is the major medical condition among patients.
#
# Cigna is the leading insurance provider.
#
# Pencilin is the most prescribed medication.
#
# the smith and sons is the high bill paying hospital.
#
# From the Analysis above, we can see the correlation between each condition with other factors such as Age, Blood type,... as well as the medication usage. The charts also show average stay duration for each condition, and their test result.
#
# we can make important decision  insurance companies (improving the benefits for patients with pre-existing conditions).
#
# some limitation:From the results, we might want to dig deeper into other elements (for example: do test results have any impact on the discharge date for each patient according to their conditions?)

# %% [markdown]
# # Machine Learning

# %%
data.drop('Insurance Provider', axis=1, inplace=True)
data.drop('Billing Amount', axis=1, inplace=True)
data.drop('Name', axis=1, inplace=True)
data.drop('Doctor', axis=1, inplace=True)
data.drop('Hospital', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lc=LabelEncoder()
cols=['Gender', 'Blood Type', 'Medical Condition','Admission Type', 'Medication','Test Results']
for i in cols:
  data[i]=lc.fit_transform(data[i])

# %%
data.head()
# Out:
#    Age  Gender  Blood Type  Medical Condition  Admission Type  Medication  \
# 0   81       0           7                  3               0           0
# 1   35       1           6                  1               1           2
# 2   61       1           5                  5               1           2
# 3   49       1           5                  1               2           4
# 4   51       1           7                  0               2           3
#
#    Test Results  Days Hospitalized
# 0             1                 14
# 1             2                 14
# 2             2                 30
# 3             0                  1
# 4             2                 24

# %% [markdown]
# # Random Forest Classifier

# %%
X=data.drop(['Test Results'],axis=1)
y=data['Test Results']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state = 26)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = RandomForestClassifier(n_estimators=100)
model1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = model1.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.33

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state = 26)

# %%
modle3=DecisionTreeClassifier()
modle3.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = modle3.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.32866666666666666

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .30, random_state = 26)

# %%
model4= KNeighborsClassifier(n_neighbors=3)
model4.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
predictions = model4.predict(X_test)
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.343
